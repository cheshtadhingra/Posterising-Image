# %% [markdown]
# ##Converting an Image to Cartoon Version
#
# This is my first computer vision project in which I have learnt how to convert an image to it's cartoon version. As hard as the description for the project might sound, the process is pretty easy.
# Here I have simplified it into these simple steps:
# 1. Install the necessary packages
# 2. Loading the image using the library of your choice, I am using Image from the PIL Library.
# 3. Posterising directly using the posterize funcition from the ImageOps
# 4. Display

# %%
pip install opencv-python  #use this only if you don't have the library pre installed in your navigator
# Out:
# ...
#                                               0.0/38.1 MB ? eta -:--:--
#                                               0.1/38.1 MB 1.7 MB/s eta 0:00:22
#                                               0.2/38.1 MB 2.0 MB/s eta 0:00:20
#                                               0.3/38.1 MB 2.0 MB/s eta 0:00:20
#                                               0.5/38.1 MB 2.7 MB/s eta 0:00:15
#                                               0.7/38.1 MB 3.1 MB/s eta 0:00:13
#                                               0.9/38.1 MB 3.1 MB/s eta 0:00:12
#      -                                        1.1/38.1 MB 3.5 MB/s eta 0:00:11
#      -                                        1.5/38.1 MB 3.9 MB/s eta 0:00:10
#      -                                        1.8/38.1 MB 4.2 MB/s eta 0:00:09
#      --                                       2.0/38.1 MB 4.1 MB/s eta 0:00:09
#      --                                       2.0/38.1 MB 3.9 MB/s eta 0:00:10
# ...

# %% [markdown]
# Importing the Required Packages

# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageOps, ImageFilter

# %% [markdown]
# Load the Image

# %%
img = Image.open("Desktop/image.jpg")

# %% [markdown]
# Posterising/Cartoonising the Image using the ImageOps Posterize

# %%
cartoon = ImageOps.posterize(img, 2)

# %% [markdown]
# Converting the image to GrayScale

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %% [markdown]
# Displaying the original image

# %%
plt.figure(figsize=(2,2))
plt.imshow(img)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %% [markdown]
# Displaying the posterised image

# %%
plt.figure(figsize=(2,2))
plt.imshow(cartoon)
plt.axis("off")
plt.title("Cartoon Image")
plt.show()
